# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 905.3/905.3 kB 14.9 MB/s eta 0:00:00
# ...

# %%
# Load YOLO11n, train it on COCO128 for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('yolo11n.pt')
# model('https://ultralytics.com/images/bus.jpg')
model('/content/drive/MyDrive/Genuin Assignment/single_class_ip/9EzLjffjY2E.mp4')
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/1066) /content/drive/MyDrive/Genuin Assignment/single_class_ip/9EzLjffjY2E.mp4: 384x640 1 zebra, 158.8ms
# video 1/1 (frame 2/1066) /content/drive/MyDrive/Genuin Assignment/single_class_ip/9EzLjffjY2E.mp4: 384x640 1 zebra, 151.4ms
# video 1/1 (frame 3/1066) /content/drive/MyDrive/Genuin Assignment/single_class_ip/9EzLjffjY2E.mp4: 384x640 1 zebra, 131.5ms
# ...

# %%
from ultralytics import YOLO
import cv2
from google.colab.patches import cv2_imshow

# Load the YOLO model
model = YOLO("yolo11n.pt")  # Replace with your YOLO model path

# Stream the video for inference
video_path = "/content/drive/MyDrive/Genuin Assignment/single_class_ip/9EzLjffjY2E.mp4"
results = model(source=video_path, stream=True)  # Stream=True to process frame by frame

# Process each frame
for r in results:
    frame = r.orig_img  # Get the original frame
    boxes = r.boxes  # Bounding box outputs

    for box in boxes:
        # Extract bounding box details
        x1, y1, x2, y2 = map(int, box.xyxy[0])  # Bounding box coordinates
        confidence = box.conf[0]  # Confidence score
        cls = box.cls[0]  # Class ID
        print(x1, y1, x2, y2)
